# %% [markdown]
# ##Q1)What is Simple Linear Regression?
# ##Ans- Simple Linear Regression is a statistical technique used to model the relationship between two variables: one independent variable (X) and one dependent variable (Y). The goal is to predict the value of Y based on X by fitting a straight line to the data. This line is expressed as Y=mX+c, where 𝑚 represents the slope (rate of change) and 𝑐 is the y-intercept (value of 𝑌 when 𝑋=0). It is widely used in forecasting and establishing relationships in data.
#
#
# ##Q2)What are the key assumptions of Simple Linear Regression?
#
# ##Ans-
#
#
#
# ##1.   **Linearity**: The relationship between the independent and dependent variables is linear. A scatter plot of 𝑋 and 𝑌 should form a straight-line pattern.
#
# ##2.   **Independence**: Observations in the dataset are independent of each other. No patterns like time-based dependencies should exist.
#
# ##3.   **Homoscedasticity**: The variance of residuals (errors) should be constant across all levels of 𝑋. This ensures that predictions are consistent.
#
# ##4.   **Normality**: Residuals should be normally distributed, which can be checked using Q-Q plots or statistical tests. This assumption ensures valid hypothesis testing and confidence intervals.
#
# ##Q3)What does the coefficient 𝑚 represent in the equation 𝑌 = 𝑚𝑋+𝑐?
#
# ##Ans-The slope 𝑚 quantifies how much 𝑌 changes for a one-unit increase in 𝑋. For example, in predicting house prices based on area, if 𝑚 = 2000, it means the price increases by $2000 for each additional square foot of area. The sign of 𝑚 indicates the direction: positive 𝑚 means a direct relationship, and negative 𝑚 implies an inverse relationship.
#
# ##Q4)What does the intercept 𝑐 represent in the equation 𝑌 = 𝑚𝑋+𝑐?
#
# ##Ans-The intercept 𝑐 is the value of 𝑌 when 𝑋 = 0. It provides the baseline prediction in the absence of any influence from 𝑋. For example, if 𝑐 = 5000 in the house price model, it means the starting price of a house, even with zero area, is $5000. While often not meaningful in real-world contexts (as zero 𝑋 may not be realistic), it helps in defining the regression line mathematically.
#
# ##Q5)How do we calculate the slope 𝑚 in Simple Linear Regression?
#
# ##Ans-The slope 𝑚 is calculated using the formula:
#
# ![Screenshot (61).png](data:image/png;base64,...)
#
#
# ##Here, 𝑋𝑖 and 𝑌𝑖 are individual data points, and x̄ and ȳ are their means. This formula minimizes the total squared differences between predicted and actual 𝑌 values, ensuring the best-fit line.
#
# ##Q6)What is the purpose of the least squares method in Simple Linear Regression?
#
# ##Ans-The least squares method minimizes the sum of squared residuals, which are the differences between actual and predicted 𝑌 values. By reducing these errors, the method ensures the regression line best fits the data. It provides the optimal slope and intercept for predicting 𝑌 with minimal error.
#
#
# ##Q7)How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
#
# ##Ans-R² measures how well the regression line explains the variability in the dependent variable. It ranges from 0 to 1:
#
#
# ##1.   R² = 0: The model explains none of the variance in 𝑌.
# ##2.   R² = 1: The model explains all the variance.
# ##For example, an R² =0.85 means 85% of the variability in 𝑌 is explained by 𝑋, indicating a strong relationship.
#
#
# ##Q8)What is Multiple Linear Regression?
#
#
# ##Ans-Multiple Linear Regression extends Simple Linear Regression to model the relationship between one dependent variable $X_1$,$X_2$,...,$X_k$. Its equation is:
# ##Y = $b_0$ + $b_1$$X_1$ + $b_2$$X_2$ +...+ $b_k$$X_k$
#
# ##Here, $b_0$ is the intercept, and $b_1$,$b_2$,...$b_k$ are the coefficients representing the contribution of each predictor.
#
#
# ##Q9)What is the main difference between Simple and Multiple Linear Regression?
#
# ##Ans-Simple Linear Regression involves one independent variable, while Multiple Linear Regression uses two or more predictors. The latter captures more complex relationships, allowing for better predictions when multiple factors influence the dependent variable.
#
#
# ##Q10)What are the key assumptions of Multiple Linear Regression?
#
# ##Ans-
#
# ##1.   Linearity: The relationship between predictors and the dependent variable is linear.
#
# ##2.   No multicollinearity: Predictors should not be highly correlated with each other.
#
# ##3.   Homoscedasticity: The variance of residuals should be constant across all levels of predictors.
#
# ##4.   Normality: Residuals should follow a normal distribution.
#
# ##5.   Independence: Observations must be independent.
#
#
# ##Q11)What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
#
#
# ##Ans-Heteroscedasticity occurs when the variance of residuals is not constant across all levels of the independent variables. This violates one of the key assumptions of regression.
#
#
#
# ##1.   **Impact:** It leads to inefficient estimates, inflated standard errors, and unreliable hypothesis tests, potentially distorting the significance of predictors.
#
# ##2.   **Example:** In financial data, residuals often increase as the value of the independent variable (e.g., income) increases, indicating heteroscedasticity.
#
#
# ##Q12)How can you improve a Multiple Linear Regression model with high multicollinearity?
#
#
# ##Ans-
#
# ##1.   **Remove Correlated Variables:** Exclude one of the highly correlated predictors based on domain knowledge.
#
# ##2.   **Regularization:** Use Ridge or Lasso regression to penalize large coefficients and reduce multicollinearity.
#
# ##3.   **Principal Component Analysis (PCA):** Transform predictors into uncorrelated components.
#
# ##4.   **Variance Inflation Factor (VIF):** Identify predictors with high VIF scores and address them.
#
# ##Q13)What are some common techniques for transforming categorical variables for use in regression models?
#
#
#
# ##Ans-
#
# ##1.   **One-Hot Encoding:** Converts categorical variables into binary columns (e.g., 'red', 'blue' becomes [1, 0] and [0, 1]).
#
# ##2.   **Label Encoding:** Assigns numeric labels to categories (e.g., 'low', 'medium', 'high' becomes 1, 2, 3).
#
# ##3.   **Dummy Variables:** Similar to one-hot encoding but avoids the dummy variable trap by dropping one category to prevent multicollinearity.
#
#
#
# ##Q14)What is the role of interaction terms in Multiple Linear Regression?
#
#
# ##Ans-Interaction terms capture the combined effect of two or more predictors on the dependent variable. For example, in predicting crop yield, the interaction between rainfall and fertilizer use may provide more insight than analyzing these factors separately. Including interaction terms can reveal complex relationships that are not evident in individual predictors.
#
#
#
# ##Q15)How can the interpretation of the intercept differ between Simple and Multiple Linear Regression?
#
#
# ##Ans-
#
# ##1.   In **Simple Linear Regression**, the intercept represents the predicted value of 𝑌 when 𝑋 = 0. In Multiple Linear Regression, it represents the predicted 𝑌 when all predictors are set to zero. This value often lacks practical interpretation, as zero values for all predictors may not be meaningful.
#
#
# ##2.   In **Multiple Linear Regression**, it represents the predicted 𝑌 when all predictors are set to zero. This value often lacks practical interpretation, as zero values for all predictors may not be meaningful.
#
#
# ##Q16)What is the significance of the slope in regression analysis, and how does it affect predictions?
#
#
# ##Ans-The slope indicates the change in the dependent variable for a one-unit increase in the independent variable, assuming all other predictors remain constant. A positive slope indicates a direct relationship, while a negative slope indicates an inverse relationship. Accurate interpretation of slopes helps in making meaningful predictions.
#
#
#
# ##Q17)How does the intercept in a regression model provide context for the relationship between variables?
#
#
# ##Ans-The intercept serves as a baseline, showing the value of the dependent variable when all predictors are zero. While it may not always have practical meaning, it provides mathematical context for the regression equation and helps define the starting point for predictions.
#
#
#
# ##Q18)What are the limitations of using R² as a sole measure of model performance?
#
#
# ##Ans-
#
# ##1.   **R²** does not indicate whether a model is appropriate or if assumptions are met.
#
# ##2.   It increases with additional predictors, even if they are irrelevant, leading to overfitting.
#
# ##3.   It doesn’t provide information about individual predictor significance or the model’s predictive accuracy on unseen data.
#
#
# ##Q19)How would you interpret a large standard error for a regression coefficient?
#
#
#
# ##Ans-A large standard error suggests high uncertainty in the coefficient estimate. This may result from multicollinearity, small sample size, or noise in the data. It indicates that the predictor's effect on the dependent variable may not be reliable or statistically significant.
#
#
# ##Q20)How can heteroscedasticity be identified in residual plots, and why is it important to address it?
#
#
#
# ##Ans-
#
# ##1.   **Identification:** A residual plot showing a funnel shape, where residuals spread out unevenly as the predicted values increase, indicates heteroscedasticity.
#
# ##2.   **Importance:** Addressing it ensures reliable hypothesis testing, efficient coefficient estimates, and valid confidence intervals. Common remedies include transforming the dependent variable or using weighted least squares.
#
#
#
# ##Q21)What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?
#
#
# ##Ans-This indicates overfitting, where the model includes irrelevant predictors that artificially inflate R². Adjusted R² penalizes for the number of predictors, so a low value suggests that some variables contribute little or no explanatory power.
#
#
# ##Q22)Why is it important to scale variables in Multiple Linear Regression?
#
#
# ##Ans-Scaling ensures that predictors are on the same scale, preventing variables with larger magnitudes from dominating the model. It is particularly important when using regularization techniques like Ridge or Lasso regression, where coefficients are penalized based on magnitude.
#
#
# ##Q23)What is polynomial regression?
#
#
# ##Ans-Polynomial regression is a type of regression analysis where the relationship between the independent variable (𝑋) and the dependent variable (𝑌) is modeled as an 𝑛-degree polynomial. It extends linear regression to capture non-linear relationships by including higher-order terms of 𝑋. The general form is:
# ##𝑌 =$b_0$ + $b_1$$X$ + $b_2$$X^2$ +...+ $b_n$$X^n$
#
#
#
# ##Q24)How does polynomial regression differ from linear regression?
#
#
# ##Ans-
#
# ##1.   **Linear Regression** assumes a straight-line relationship between 𝑋 and 𝑌, using only 𝑋 as a predictor.
#
# ##2.   **Polynomial Regression** allows for curves by including higher-degree terms ($X^2$, $X^3$,...)
#
# ##**Example:** A quadratic model (𝑌 =$b_0$ + $b_1$$X$ + $b_2$$X^2$)can fit a parabolic trend, which a linear model cannot.
#
#
#
# ##Q25)When is polynomial regression used?
#
#
# ##Ans-Polynomial regression is used when data exhibits a non-linear relationship that cannot be captured by a simple linear model. It is commonly applied in fields such as physics, economics, and biology to model complex phenomena like growth trends or diminishing returns.
#
#
# ##Q26)What is the general equation for polynomial regression?
#
#
# ##Ans-The general equation is:
# ##𝑌 =$b_0$ + $b_1$$X$ + $b_2$$X^2$ + $b_3$$X^3$  +...+ $b_n$$X^n$
#
# ##Here, $b_0$,$b_1$,$b_2$ are coefficients,𝑛 is the degree of the polynomial, and $X^n$ represents the 𝑛-th power of the independent variable.
#
#
# ##Q27)Can polynomial regression be applied to multiple variables?
#
# ##Ans-Yes, polynomial regression can be extended to include multiple independent variables. For example, with two variables $X_1$ and $X_1$ the model may include interaction and higher-order terms like $X_1^2$,$X_2^2$,$X_1$,$X_2$, etc., to capture non-linear relationships.
#
#
#
#
# ##Q28)What are the limitations of polynomial regression?
#
# ##Ans-
#
# ##1.   **Overfitting:** High-degree polynomials can model noise instead of the true trend, reducing generalization.
#
# ##2.   **Complexity:** Higher-degree models can be computationally intensive and difficult to interpret.
#
# ##3.   **Extrapolation Issues:** Polynomial models can produce unrealistic predictions outside the observed range of 𝑋.
#
#
#
# ##Q29)What methods can be used to evaluate model fit when selecting the degree of a polynomial?
#
#
# ##Ans-
#
# ##1.   **Cross-Validation:** Evaluate performance on unseen data to avoid overfitting.
#
# ##2.   **Adjusted $𝑅^2$:** Accounts for additional predictors, penalizing over-complex models.
#
# ##3.   **Residual Analysis:** Check residual plots to ensure no patterns remain.
#
# ##4.   **Metrics:** Compare Mean Squared Error (MSE) or Root Mean Squared Error (RMSE) for different degrees.
#
#
#
# ##Q30)Why is visualization important in polynomial regression?
#
#
#
# ##Ans-Visualization helps to:
#
#
#
# ##1.   Identify non-linear patterns in data.
#
# ##2.   Compare the fit of different polynomial degrees to actual data points.
#
# ##3.   Detect overfitting or underfitting through the shape of the regression curve.
#
# ##Q31)How is polynomial regression implemented in Python?
#
#
#
# ##Ans- Polynomial regression can be implemented using **PolynomialFeatures** from **sklearn.preprocessing** to transform the data into polynomial features, followed by fitting a linear regression model. Here is an example:

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
X = np.linspace(-3, 3, 100).reshape(-1, 1)  # X is 2D for sklearn
y = (2 * X**3 - 5 * X**2 + 4 * X + np.random.randn(100, 1)).ravel()  # y is 1D for sklearn

# Transform data to include polynomial features
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# Fit model
model = LinearRegression()
model.fit(X_poly, y)

# Predict and visualize
y_pred = model.predict(X_poly)

# Plot the results
plt.scatter(X, y, color='blue', label='Data points')  # Scatter plot for actual data
plt.plot(X, y_pred, color='red', label='Polynomial fit')  # Polynomial regression line
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
